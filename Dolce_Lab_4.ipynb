# %% [markdown]
# <a href="https://colab.research.google.com/github/tdolce2021/Repo_Dolce/blob/main/Dolce_Lab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stats Notebook Lab #4

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4])

# %% [markdown]
# saying x and listing numbers

# %%
# population

# %% [markdown]
# making a label of population

# %%
np.sum(x)
# Out:
# 10

# %% [markdown]
# 'np.sum' adds numbers in an array so putting 'x' as the subject to be added, the system added the numbers in x's number list

# %%
x.shape[0]
# Out:
# 4

# %% [markdown]
# accessing a list of some sort for a shape (not sure how to explain) give number of rows in an array

# %%
np.sum(x)/x.shape[0]
# Out:
# 2.5

# %% [markdown]
# taking the sum of the array and divide the number of rows and it gives 2.5

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %% [markdown]
# defining mean as the quotient of the array of numbers and the number of rows

# %%
mean(x)
# Out:
# 2.5

# %% [markdown]
# the 'mean' is the quotient of the array and rows, thus rendering 2.6

# %%
x
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# earlier, x was made as the array of numbers

# %%
x - mean(x)
# Out:
# array([-1.5, -0.5,  0.5,  1.5])

# %% [markdown]
# this equation subtracts the x (array of numbers) and the mean (2.5)

# %%
(x - mean(x))**2
# Out:
# array([2.25, 0.25, 0.25, 2.25])

# %% [markdown]
# this equation subtracts the array of numbers and the mean, then squares the answer

# %%
 def var(x):
    return mean((x - mean(x))**2)

# %% [markdown]
# 'var(x)' comes back as subtracting the array of numbers and the mean; subtracting the

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 2.5

# %%
var(x)
# Out:
# 1.25

# %%
std(x)
# Out:
# 1.118033988749895

# %% [markdown]
# ### Random Number Generator

# %% [markdown]
# $y=mx+b$

# %%
m = 75                 # multiplier
b = 74                 # increment
n = 65537              # modulus

# %%
x = 58      # seed value

# %%
X = np.zeros(50000,)

# %% [markdown]
# creates an array of zeros; in this case maybe the number used is the amount

# %%
x = (m * x + b) % n

# %% [markdown]
# giving 'x' as the equation of m x + b

# %%
for i in range(X.shape[0]):

    x = (m * x + b) % n
    
    X[i] = x

# %%
X
# Out:
# array([57338., 40519., 24297., ..., 11014., 39680., 26909.])

# %%
X /= np.max(X)

# %% [markdown]
# findng the maximum of an array of elements. 'X' is labeled as that finder

# %%
plt.plot(X[:100],'.')

# %% [markdown]
# plots 100 of the maximum array. plotted using dots

# %%
plt.hist(X);

# %% [markdown]
# made a histogram of maximum arrays labeled as X

# %%
plt.hist(X,100);

# %%
X
# Out:
# array([0.8749218 , 0.61828031, 0.37074846, ..., 0.16806287, 0.60547799,
#        0.41060502])

# %%
X
# Out:
# array([0.8749218 , 0.61828031, 0.37074846, ..., 0.16806287, 0.60547799,
#        0.41060502])

# %%
X
# Out:
# array([0.8749218 , 0.61828031, 0.37074846, ..., 0.16806287, 0.60547799,
#        0.41060502])

# %% [markdown]
# ### Random Numbers

# %%
X = np.random.random(50000,)

# %%
X
# Out:
# array([0.1786133 , 0.46070729, 0.39645995, ..., 0.75385782, 0.88461994,
#        0.216262  ])

# %%
plt.hist(X,100);

# %%
np.random.random()
# Out:
# 0.5880086831095652

# %% [markdown]
# random number generator

# %%
r = np.random.random()

# %% [markdown]
# 'r' labeled as the random number generator

# %%
r
# Out:
# 0.4989302415999062

# %%
r = np.random.randint(1,10)

# %% [markdown]
# sets 'r' to generate limits in the numbers. in this case from 1 to 10 ???

# %%
r
# Out:
# 2

# %%
r = np.random.randint(0,3,size=(1))

# %% [markdown]
# random number from 0 to 3

# %%
r[0]
# Out:
# 0

# %%
game = ['rock', 'paper', 'scissors']

# %%
game[r[0]]
# Out:
# 'rock'

# %% [markdown]
# returns one of the elements in the list 'game'. maybe the 0 position

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]

# %% [markdown]
# random numbers from 0 to 3 ??

# %%
p1,p2
# Out:
# (2, 2)

# %% [markdown]
# plots random 1 and random 2 just as a pair

# %%
p1 = np.random.randint(0,3,size=(1))[0]
p2 = np.random.randint(0,3,size=(1))[0]
game[p1],game[p2]
# Out:
# ('paper', 'paper')

# %% [markdown]
# randomizes the guesses of the elements in the 'game' list

# %%
import numpy as np

# %%
np.random.randn()
# Out:
# -0.8227786729680922

# %% [markdown]
# random number generator

# %%
numbers  = np.random.randn(2,4)

# %%
numbers
# Out:
# array([ 1.51083635, -0.39660247,  0.9840288 , -1.75514713, -0.27954888,
#         0.19280287, -1.40396196,  0.59159141])

# %%
numbers.shape
# Out:
# (8,)

# %%
numbers = numbers.reshape(-1)

# %%
numbers.shape
# Out:
# (8,)

# %% [markdown]
# randomizes an array of numbers and shape (numbers of rows in an array)

# %%
# numbers= np.array([1,2,2,3,3,3,4,4,4,4])

# %%
numbers = np.random.randn(100000,)

# %%
numbers.shape
# Out:
# (1000000,)

# %%
plt.hist(numbers,100);

# %% [markdown]
# since 'numbers' is set to return random numbers, this histogram gives 1oo random numbers (i think)

# %%
numbers = np.random.rand(1000000,)

# %%
plt.hist(numbers,100);

# %%
np.random.seed(12345)
data = np.random.randn(2, 100)

plt.figure(1, figsize=(9, 9))


plt.subplot(2,2,1)
plt.hist(data[0])

plt.subplot(2,2,2)
plt.scatter(data[0], data[1])

plt.subplot(2,2,3)
plt.plot(data[0], data[1])

plt.subplot(2,2,4)
plt.hist2d(data[0], data[1])

plt.show()

# %% [markdown]
# generates random values for the different graphs

# %% [markdown]
# Normal Dist Data

# %%
x = 50*np.random.randn(10000)

# %%
plt.hist(x);

# %%
x = np.random.rand(1000,)

# %%
plt.hist(x**2);

# %%
mu = 100  # mean of distribution
sigma = 15  # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

# %%
n,bins,patches = plt.hist(x)

# %% [markdown]
# 'n,bins,patches' are things required to make a histogram;
# plotting 'x' meant adding the mu and sigma

# %%
bins
# Out:
# array([ 37.73712055,  49.11784683,  60.49857311,  71.87929939,
#         83.26002567,  94.64075195, 106.02147823, 117.40220451,
#        128.78293078, 140.16365706, 151.54438334])

# %% [markdown]
# define the number of equal-width bins in the range

# %%
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(y)

# %% [markdown]
# the equation to a line consisting of: 1 divided by the square root of 2 mulitplied by pi and multiplying that by sigma x the exponents of negative 0.5 multiplied by 1 divided by sigma (15) multiplied by the difference bins and mu (100)

# %%
num_bins = 50
n,bins,patches = plt.hist(x, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %%
def mean(x):
    return np.sum(x)/x.shape[0]

# %%
def var(x):
    return mean((x - mean(x))**2)

# %%
def std(x):
    return np.sqrt(var(x))

# %%
mean(x)
# Out:
# 100.04075183020417

# %%
std(x)
# Out:
# 15.04055138379747

# %% [markdown]
# # Normal Random Number Generator

# %%
#CDF PDF

# %%
x = np.linspace(-10,10,100)
y = 2.71**(-x**2)
plt.plot(x,y)

# %% [markdown]
# $e^{-x^2}$

# %% [markdown]
# ![alt text](https://wikimedia.org/api/rest_v1/media/math/render/svg/4abaca87a10ecfa77b5a205056523706fe6c9c3f)

# %%
def normal_pdf(x,mu,sigma):
  
  return (1/(np.sqrt(2*np.pi*sigma**2)))*np.exp((-(x-mu)**2)/(2*sigma**2))

# %%
x = np.linspace(-6,6,100)

# %%
mu = 3

# %%
sigma = 7

# %%
pdf = normal_pdf(mu,sigma,x) #Use Normal for demo, replace with custom function pdf

# %%
plt.plot(x,pdf,'.')
plt.plot(x,y,'g.')

# %%
def partial_sums(x):

  y = np.zeros(x.shape)
  
  for n in range(x.shape[0]):
    
    y[n] = np.sum(x[0:n])
    
  y = y / np.max(y)
    
  return y

# %%
cdf = partial_sums(pdf)

# %%
plt.plot(x,cdf,'.');

# %%
plt.plot(x,pdf,'g.');

# %%
d_cdf = cdf[1:] - cdf[0:-1] #Demo to show that the diff of the cdf gives you back the pdf
plt.plot(x[1:],d_cdf,'.');  #Not required for sampling

# %%
d_cdf = pdf[1:] - cdf[0:-1] 
plt.plot(x[1:],d_cdf,'.');

# %%
d_cdf = pdf[1:] - pdf[0:-1] 
plt.plot(x[1:],d_cdf,'.');

# %%
d_cdf = pdf[-1:] - pdf[0:-1] 
plt.plot(x[1:],d_cdf,'r+');

# %%
plt.plot(cdf,x,'.');

# %%
plt.plot(cdf,x,'.');
plt.plot(pdf,x,'m<');

# %%
def find_nearest(array, value):

  idx = np.argmin(np.abs(array - value))
  
  return idx

# %%
find_nearest(cdf, 0.1)
# Out:
# 7

# %%
x[7]
# Out:
# -5.151515151515151

# %%
xr = np.random.random((10000,))

# %%
w = np.zeros(xr.shape[0])

for i in range(xr.shape[0]):
  
  w[i] = x[find_nearest(cdf, xr[i])]

# %%
w.shape
# Out:
# (10000,)

# %%
plt.hist(w,50);

# %%
num_bins = 50
n,bins,patches = plt.hist(w, num_bins, density=1)
y = ((1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * (1 / sigma * (bins - mu))**2))
plt.plot(bins,y)

# %% [markdown]
# # Random Color

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
z = np.random.randint(0,255,size=(1,1,3))

# %%
z
# Out:
# array([[[ 88, 100, 117]]])

# %% [markdown]
# z is labeled to generate random numbers from

# %%
z = np.random.randint(0,255,size=(10,10,3))

# %%
plt.imshow(z)

# %% [markdown]
# plotting z using different colors on the graph at random orders

# %%
z = np.zeros((100,100,3))

# %%
z.shape
# Out:
# (100, 100, 3)

# %% [markdown]
# defines shape using 'z' array to make shape

# %%
plt.imshow(z)

# %%
z = 0*np.ones((10,10,3))

# %%
plt.imshow(z)

# %%
z = 255*np.ones((10,10,3))

# %%
plt.imshow(z)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
z = np.ones((10,10,3))

z[:,:,0] = 1
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 1
z[:,:,2] = 0

plt.imshow(z)

# %%
z = np.ones((10,10,3))

z[:,:,0] = 0
z[:,:,1] = 0
z[:,:,2] = 1

plt.imshow(z)

# %%
plt.hist(np.random.randn(1000,)/6 + 1/2)
# Out:
# (array([  4.,  19.,  70., 164., 224., 233., 171.,  75.,  31.,   9.]),
#  array([-0.02516891,  0.07776245,  0.18069382,  0.28362518,  0.38655655,
#          0.48948791,  0.59241928,  0.69535064,  0.798282  ,  0.90121337,
#          1.00414473]),
#  <a list of 10 Patch objects>)

# %%
for _ in range(100):
    z = np.ones((10,10,3))

    r = np.random.randn()/6 + 1/2
    g = np.random.randn()/6 + 1/2
    b = np.random.randn()/6 + 1/2

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.47243130766189617 0.6468829250181908 0.44008524181527253
# 0.3549378489426249 0.38418342127874017 0.5826543086878607
# 0.5333657426404801 0.4917226735090131 0.3593711758369618
# 0.34313756781430993 0.5413785729033012 0.4938597373895947
# 0.3688519344525235 0.6141121195321956 0.9241324606517862
# 0.8285279762145956 0.5740000770534216 0.5043951514990355
# 0.7639828965126509 0.285577064199409 0.647222782397643
# 0.30597146604804226 0.5366701757413442 0.4574518946921729
# 0.4467172167859182 0.44109727539570126 0.6000758226267886
# 0.5419355068656967 0.5051370881451974 0.3931892090706525
# 0.6334916315246805 0.5721898049614027 0.3886796584637702
# 0.6065313361010937 0.354797917708917 0.5281038613950302
# 0.6299553454808684 0.760548024690457 0.5292257368933599
# 0.37308915954641214 0.47136015131964953 0.5485790775506973
# ...

# %% [markdown]
# generating random numbers to generate different colors

# %%
for i in range(100):

    z = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    print(r,g,b)

    z[:,:,0] = r
    z[:,:,1] = g
    z[:,:,2] = b

    plt.imshow(z);
    plt.show()
# Out:
# 0.5425487138578239 0.3997953233132263 0.05506232643735831
# 0.7799538182070364 0.3972956350642568 0.09190214588093437
# 0.489787727505142 0.9867886586274328 0.995080265033436
# 0.25547004745242685 0.7881299639551721 0.3515884409842098
# 0.739387065420093 0.6043467724587559 0.2871940485940999
# 0.7076195237963664 0.20066109051362102 0.9939019666197271
# 0.9486020742218577 0.8940395335137279 0.8774542901753344
# 0.549785794551599 0.8976126030005204 0.6655601079325444
# 0.3515766789870556 0.9143795271827477 0.5348469182465925
# 0.2546866511083715 0.2155738252732171 0.9984713217004468
# 0.9303819699093482 0.8869345609817267 0.19303822361727585
# 0.5556666825929254 0.24015852482207256 0.3652588032561407
# 0.13091129703857363 0.4832369505369807 0.20644804216665247
# 0.5577770358726646 0.5329789382522689 0.6536877098406905
# 0.44010737656240195 0.1916734446337418 0.2552606157291455
# 0.38034211985846067 0.07070644304690632 0.5186852090075806
# ...

# %% [markdown]
# random colors generated from different numbers that produced different tones

# %%
z1 = np.ones((10,10,3))
z1[:,:,0] = np.random.rand()
z1[:,:,1] = np.random.rand()
z1[:,:,2] = np.random.rand()

z2 = np.ones((10,10,3))
z2[:,:,0] = np.random.rand()
z2[:,:,1] = np.random.rand()
z2[:,:,2] = np.random.rand()

zavg = (z1+z2)/2

z1a = (z1+zavg)/2
z2a = (z2+zavg)/2

z3 = np.hstack((z1,z1a,zavg,z2a,z2))

plt.imshow(z3);
plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z1[:,:,0] = np.random.rand()
    z1[:,:,1] = np.random.rand()
    z1[:,:,2] = np.random.rand()

    z2 = np.ones((10,10,3))
    z2[:,:,0] = np.random.rand()
    z2[:,:,1] = np.random.rand()
    z2[:,:,2] = np.random.rand()

    zavg = (z1+z2)/2

    z1a = (z1+zavg)/2
    z2a = (z2+zavg)/2

    z3 = np.hstack((z1,z1a,zavg,z2a,z2))

    plt.imshow(z3);
    plt.show()

# %%
for i in range(100):
    
    z1 = np.ones((10,10,3))
    z2 = np.ones((10,10,3))

    r = np.random.rand()
    g = np.random.rand()
    b = np.random.rand()

    z1[:,:,0] = r
    z1[:,:,1] = g
    z1[:,:,2] = b
    
    z2[:,:,0] = 1-r
    z2[:,:,1] = 1-g
    z2[:,:,2] = 1-b

    z3 = np.hstack((z1,z2))

    plt.imshow(z3);
    plt.show()

# %% [markdown]
# https://lospec.com/palette-list

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib
import imageio
from PIL import Image

def get_colors_lospec(url):
    im = imageio.imread(url)
    rgb_list = (im/255)[0,:,0:3]
    float_list = list(np.linspace(0,1,len(rgb_list)))    
    cdict = dict()
    for num, col in enumerate(['red', 'green', 'blue']):
        col_list = [[float_list[i], rgb_list[i][num], rgb_list[i][num]] for i in range(len(float_list))]
        cdict[col] = col_list
    cmp = mcolors.LinearSegmentedColormap('my_cmp', segmentdata=cdict, N=256)
    return cmp

# %%
url = 'https://lospec.com/palette-list/agb-32x.png'

# %%
url = 'https://lospec.com/palette-list/agb-1x.png'

# %%
url = 'https://lospec.com/palette-list/moondrom-1x.png'

# %%
im = imageio.imread(url)

# %%
plt.imshow(im);

# %%
z = np.random.randint(0,255,size=(10,10))

# %%
plt.imshow(z, cmap=get_colors_lospec(url))
plt.colorbar();

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sqrt(x**2 + y**2)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()

# %%
x, y = np.mgrid[-5:5:0.05, -5:5:0.05]
z = np.sin(3*y)*np.sin(3*x)

plt.imshow(z, cmap=get_colors_lospec(url));
plt.show()
